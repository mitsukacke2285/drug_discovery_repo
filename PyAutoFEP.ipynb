# %% [markdown]
# <a href="https://colab.research.google.com/github/mitsukacke2285/drug_discovery_repo/blob/main/PyAutoFEP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt update
# Out:
# Hit:1 https://cli.github.com/packages stable InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Fetched 129 kB in 1s (93.0 kB/s)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ...

# %%
# !sudo apt search gromacs
# Out:
# Sorting... Done
# Full Text Search... Done
# gromacs/jammy,now 2021.4-2 amd64 [installed]
#   Molecular dynamics simulator, with building and analysis tools
#
# gromacs-data/jammy,now 2021.4-2 all [installed,automatic]
#   GROMACS molecular dynamics sim, data and documentation
#
# gromacs-mpi/jammy 2021.4-2 amd64
#   Molecular dynamics sim, binaries for MPI parallelization
#
# libgromacs-dev/jammy 2021.4-2 amd64
#   GROMACS molecular dynamics sim, development kit
#
# libgromacs6/jammy,now 2021.4-2 amd64 [installed,automatic]
#   GROMACS molecular dynamics sim, shared libraries
#
# libjgromacs-java/jammy 1.0-1.1 all
#   library for molecular dynamics trajectory analysis
#
# libjgromacs-java-doc/jammy 1.0-1.1 all
#   library for molecular dynamics trajectory analysis (documentation)
#
# libnblib-dev/jammy 2021.4-2 amd64
#   GROMACS molecular dynamics sim, NB-LIB development kit
#
# libnblib0/jammy 2021.4-2 amd64
#   GROMACS molecular dynamics sim, NB-LIB shared libraries
#
# ...

# %%
# !sudo apt install gromacs
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# gromacs is already the newest version (2021.4-2).
# 0 upgraded, 0 newly installed, 0 to remove and 38 not upgraded.

# %%
# !wget https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# !chmod +x Miniconda3-latest-Linux-x86_64.sh
# !bash ./Miniconda3-latest-Linux-x86_64.sh -b -f -p /usr/local
# Out:
# --2025-10-25 09:11:16--  https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.32.241, 104.16.191.158, 2606:4700::6810:20f1, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.32.241|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162129736 (155M) [application/octet-stream]
# Saving to: ‘Miniconda3-latest-Linux-x86_64.sh.1’
#
# Miniconda3-latest-L 100%[===================>] 154.62M   233MB/s    in 0.7s
#
# 2025-10-25 09:11:17 (233 MB/s) - ‘Miniconda3-latest-Linux-x86_64.sh.1’ saved [162129736/162129736]
#
# PREFIX=/usr/local
# Unpacking bootstrapper...
# Unpacking payload...
#
# Installing base environment...
#
# Preparing transaction: ...working... done
# Executing transaction: ...working... done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
# ...

# %%
# !git clone https://github.com/luancarvalhomartins/PyAutoFEP.git
# Out:
# fatal: destination path 'PyAutoFEP' already exists and is not an empty directory.

# %%
y
# Create a conda environment and activate it.
# !conda create -n PyAutoFEP
# !conda activate PyAutoFEP

# Install stuff
# !conda install -c conda-forge rdkit
# !conda install -c conda-forge openbabel
# !conda install matplotlib networkx pip
# Use pip to install pymbar and alchemlyb
# !pip install pymbar alchemlyb==0.6.0
# Out:
# Jupyter detected...
# 2 channel Terms of Service accepted
# done
# Channels:
#  - defaults
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 25.7.0
#     latest version: 25.9.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/PyAutoFEP
#
#
#
# Proceed ([y]/n)? y
#
#
# ...
#
# done
# done
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate PyAutoFEP
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
#
# CondaError: Run 'conda init' before 'conda activate'
#
# Jupyter detected...
# 2 channel Terms of Service accepted
# Channels:
#  - conda-forge
#  - defaults
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 25.7.0
#     latest version: 25.9.1
#
# Please update conda by running
#
# ...

# %%
# !conda tos accept --override-channels --channel https://repo.anaconda.com/pkgs/main
# !conda tos accept --override-channels --channel https://repo.anaconda.com/pkgs/r
# Out:
# accepted Terms of Service for https://repo.anaconda.com/pkgs/main
# accepted Terms of Service for https://repo.anaconda.com/pkgs/r

# %%
# !sudo apt install openbabel
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# openbabel is already the newest version (3.1.1+dfsg-6ubuntu5).
# 0 upgraded, 0 newly installed, 0 to remove and 38 not upgraded.

# %%
# !conda tos accept --override-channels --channel https://repo.anaconda.com/pkgs/main
# !conda tos accept --override-channels --channel https://repo.anaconda.com/pkgs/r
# Out:
# accepted Terms of Service for https://repo.anaconda.com/pkgs/main
# accepted Terms of Service for https://repo.anaconda.com/pkgs/r

# %%
# !conda tos accept --override-channels --channel https://repo.anaconda.com/pkgs/main
# !conda tos accept --override-channels --channel https://repo.anaconda.com/pkgs/r
# Out:
# accepted Terms of Service for https://repo.anaconda.com/pkgs/main
# accepted Terms of Service for https://repo.anaconda.com/pkgs/r

# %%
# !tar -xvzf PyAutoFEP/workdir.tgz
# Out:
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.user.com.dropbox.attrs'
# gc2_data/
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.user.com.dropbox.attrs'
# gc2_data/.ipynb_checkpoints/
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.user.com.dropbox.attrs'
# gc2_data/.ipynb_checkpoints/PyAutoFEP tutorial plots-checkpoint.ipynb
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.user.com.dropbox.attrs'
# gc2_data/experimental_affinity.csv
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.user.com.dropbox.attrs'
# gc2_data/PyAutoFEP tutorial plots.ipynb
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.user.com.dropbox.attrs'
# lig_data/
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.user.com.dropbox.attrs'
# lig_data/FXR_76.mol
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.user.com.dropbox.attrs'
# lig_data/FXR_12.mol
# ...

# %%
# Convert smiles in mol2 files
# !obabel fxr_fe2_selected_ligands.smi -Oligand.mol --gen3d -m
# Out:
# 6 molecules converted
# 6 files output. The first is ligand1.mol

# %%
# Create a dir
# !mkdir lig_data
# Out:
# mkdir: cannot create directory ‘lig_data’: File exists

# %%
# Batch rename and move the mol files
# !for eachfile in ligand*.mol; do mv $eachfile "lig_data/$(head -n1 $eachfile).mol"; done

# %% [markdown]
# # lig_data must contain:
# > ls lig_data
# FXR_12.itp FXR_74.itp FXR_76.itp FXR_84.itp FXR_85.itp FXR_88.itp
# FXR_12.mol FXR_74.mol FXR_76.mol FXR_84.mol FXR_85.mol FXR_88.mol

# %%
# receptor_data must contain:
# !grep "HETATM.*9MV" receptor_data/5q17.pdb > receptor_data/9mv.pdb

# %%
# Replace residue names
# !./rename_res.sh receptor_data/5q17_processed.pdb

# %%
# !chmod +x PyAutoFEP/generate_perturbation_map.py

# %%
# !pip install networkx

# %%
import os
os.environ["MPLBACKEND"] = "Agg"

# %%
# Generate a star map
# !python /content/PyAutoFEP/generate_perturbation_map.py --map_type=star --map_bias=FXR_12 --input lig_data/*.mol
